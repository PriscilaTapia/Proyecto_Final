# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

lista_noticias = []

#marcado de página

url = requests.get("https://www.bbc.com/mundo/topics/cpzd498zkxgt")
content = url.content
statusCode = url.status_code
if statusCode == 200:
    site = BeautifulSoup(content, 'html.parser') #parse (analizador)

    #bloque donde se encuantra cada noticia
    noticias = site.findAll('article', class_ = 'qa-post gs-u-pb-alt+ lx-stream-post gs-u-pt-alt+ gs-u-align-left') 

        #iteración para obtener los datos que queremos extraer 
    for noticia in noticias:
        titulo = noticia.find('a', class_ =  'qa-heading-link lx-stream-post__header-link').text
        cuerpo_noticia = noticia.find('div', class_ = 'lx-stream-related-story').text
        link = noticia.find('div', class_='gel-3/8@l').a.get('href')
        lista_noticias.append([titulo.strip(),cuerpo_noticia,link])
    
    #Generar dataframe
    news = pd.DataFrame(lista_noticias, columns=['Titulo','Cuerpo','Link'])
else:
    print ("Error en la pagina")
#exportamos dataframe
#news.to_csv('noticias.csv', index=False)
#print(lista_noticias)

# %%
news
# Out:
#                                               Titulo  \
# 0  El bebé en Reino Unido que recibió gratis un m...
# 1  Las sorprendentes revelaciones del mayor estud...
# 2  Sweet Anita: la streamer con síndrome de Toure...
# 3  Los países de América Latina que administran u...
# 4  La enfermera que "vacunó" a miles contra el co...
# 5  "No pude mirarme en el espejo por mucho tiempo...
# 6  8 respuestas sobre la variante delta, la más c...
# 7  Indonesia pondrá fin a las pruebas de virginid...
# 8  "Hoy, el que no tiene más de un par de ojos es...
# 9  No todos los narcisistas son iguales, ¿qué los...
#
#                                               Cuerpo  \
# 0  Megan Willis, madre de Edward, dijo que sentía...
# 1  El aumento de peso a medida que envejecemos no...
# 2  Anita transmite por internet a miles de seguid...
# 3  Aunque algunos países del mundo -y de América ...
# 4  Las autoridades en Frisia, Alemania, temen que...
# 5  Juan nunca quiso ser modelo, hasta que una age...
# 6  La variante delta del coronavirus ya se convir...
# 7  Durante décadas, Indonesia exigió a sus mujere...
# 8  El escritor chileno, autor de "Un verdor terri...
# 9  La descripción de un narcisista es, por lo gen...
#
#                                       Link
# 0                 /mundo/noticias-58200247
# 1                 /mundo/noticias-58200846
# 2                 /mundo/noticias-58189101
# 3  /mundo/noticias-america-latina-58152738
# 4   /mundo/noticias-internacional-58188268
# 5                 /mundo/noticias-58163471
# 6                 /mundo/noticias-58177203
# 7   /mundo/noticias-internacional-58173821
# 8                 /mundo/noticias-57943009
# 9                 /mundo/noticias-58145595
